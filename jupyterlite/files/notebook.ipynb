# %% [markdown]
# # Root Notebook
#
# This is a sample notebook.
#
# Try running this code:
#
# ```python
# x = 1
# y = "2"
# print(str(x) + y)
# ```

# %%
# Click in here and then shift + enter to run the cell
x = 1
y = "2"
print(str(x) + y)
